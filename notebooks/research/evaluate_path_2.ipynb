# %% [markdown]
# # Get data

# %% [markdown]
# ## Peeringdb

# %%
import json
from pathlib import Path
import pandas as pd

filepath = Path('../../preprocessing/data/peeringdb/peeringdb_2_dump_2025_10_21.json')

with filepath.open('r', encoding='utf-8') as f:
    dump = json.load(f)

# extract the net.data section and load into a DataFrame
net_data = dump.get('net', {}).get('data')
if net_data is None:
    raise KeyError("JSON does not contain 'net' -> 'data' structure")

net_df = pd.DataFrame(net_data)
net_df['asn'] = net_df['asn'].astype(int)
net_df = net_df[net_df['info_type'] != '']

# show a quick preview
net_df.head()
# Out:
#    id  org_id                         name  \
# 0   1    8897  GTT Communications (AS4436)
# 1   2      14          Akamai Technologies
# 2   3      17           DALnet IRC Network
# 3   5    9350                     Swisscom
# 4   6      23           Cox Communications
#
#                                        aka name_long  \
# 0  Formerly known as nLayer Communications
# 1
# 2
# 3                                  IP-Plus
# 4                       Cox Communications
#
#                       website  \
# 0          http://www.gtt.net
# 1     https://www.akamai.com/
# 2          http://www.dal.net
# 3     http://www.swisscom.com
# 4  http://www.cox.com/peering
#
#                                         social_media    asn looking_glass  \
# 0  [{'service': 'website', 'identifier': 'http://...   4436
# 1  [{'service': 'website', 'identifier': 'https:/...  20940
# 2  [{'service': 'website', 'identifier': 'http://...  31800
# 3  [{'service': 'website', 'identifier': 'http://...   3303
# 4  [{'service': 'website', 'identifier': 'http://...  22773
#
#                         route_server  ... policy_ratio policy_contracts  \
# 0                                     ...         True         Required
# 1                                     ...        False     Not Required
# 2                                     ...        False     Not Required
# 3  telnet://route-server.ip-plus.net  ...         True         Required
# 4                                     ...        False         Required
#
#   allow_ixp_update               status_dashboard  rir_status  \
# 0            False                           None          ok
# 1            False  https://www.akamaistatus.com/          ok
# 2            False                                         ok
# 3            False                                         ok
# 4            False                                         ok
#
#      rir_status_updated  logo               created               updated  \
# 0  2024-06-26T04:47:55Z  None  2004-07-28T00:00:00Z  2022-07-27T05:33:22Z
# 1  2024-06-26T04:47:55Z  None  2004-07-28T00:00:00Z  2025-10-20T12:16:12Z
# 2  2024-06-26T04:47:55Z  None  2004-07-28T00:00:00Z  2025-01-09T13:42:07Z
# 3  2024-06-26T04:47:55Z  None  2004-07-28T00:00:00Z  2025-08-12T06:33:30Z
# 4  2024-06-26T04:47:55Z  None  2004-07-28T00:00:00Z  2022-11-28T22:55:17Z
#
#    status
# 0      ok
# 1      ok
# 2      ok
# 3      ok
# 4      ok
#
# [5 rows x 41 columns]

# %% [markdown]
# ## Paths

# %%
path_df = pd.read_csv('../../scripts/as_visibility2.csv')
path_df.head()
# Out:
#    asn  seen_peers_path  visibility_path  seen_peers_origin  \
# 0    1               45         0.398230                 45
# 1    2               84         0.743363                 82
# 2    3               86         0.761062                 87
# 3    4               90         0.796460                 90
# 4    5               45         0.398230                 43
#
#    visibility_origin  centrality_mean  endprox_mean  nonterminal_rate  \
# 0           0.398230         0.002632      0.001316          0.010526
# 1           0.725664         0.183717      0.091859          0.298013
# 2           0.769912         0.110788      0.055394          0.225989
# 3           0.796460         0.003306      0.001653          0.008264
# 4           0.380531         0.101111      0.050556          0.216667
#
#    path_occurrences  origin_occurrences  total_unique_paths  total_peers
# 0                95                  45             7611576          113
# 1               302                  82             7611576          113
# 2               354                  87             7611576          113
# 3               242                  90             7611576          113
# 4                60                  43             7611576          113

# %% [markdown]
# ## Merge data

# %%
merged_df = pd.merge(net_df, path_df, on='asn', how='left')
merged_df.head()
# Out:
#    id  org_id                         name  \
# 0   1    8897  GTT Communications (AS4436)
# 1   2      14          Akamai Technologies
# 2   3      17           DALnet IRC Network
# 3   5    9350                     Swisscom
# 4   6      23           Cox Communications
#
#                                        aka name_long  \
# 0  Formerly known as nLayer Communications
# 1
# 2
# 3                                  IP-Plus
# 4                       Cox Communications
#
#                       website  \
# 0          http://www.gtt.net
# 1     https://www.akamai.com/
# 2          http://www.dal.net
# 3     http://www.swisscom.com
# 4  http://www.cox.com/peering
#
#                                         social_media    asn looking_glass  \
# 0  [{'service': 'website', 'identifier': 'http://...   4436
# 1  [{'service': 'website', 'identifier': 'https:/...  20940
# 2  [{'service': 'website', 'identifier': 'http://...  31800
# 3  [{'service': 'website', 'identifier': 'http://...   3303
# 4  [{'service': 'website', 'identifier': 'http://...  22773
#
#                         route_server  ... visibility_path seen_peers_origin  \
# 0                                     ...        0.345133               0.0
# 1                                     ...        0.840708              94.0
# 2                                     ...        0.345133              47.0
# 3  telnet://route-server.ip-plus.net  ...        0.743363              85.0
# 4                                     ...        0.716814              81.0
#
#   visibility_origin  centrality_mean  endprox_mean nonterminal_rate  \
# 0          0.000000         0.506838      0.253419         1.000000
# 1          0.831858         0.310215      0.155108         0.629129
# 2          0.415929         0.000000      0.000000         0.000000
# 3          0.752212         0.791847      0.395923         0.993558
# 4          0.716814         0.573053      0.286527         0.988001
#
#   path_occurrences origin_occurrences  total_unique_paths  total_peers
# 0             39.0                0.0           7611576.0        113.0
# 1          25974.0               94.0           7611576.0        113.0
# 2             39.0               47.0           7611576.0        113.0
# 3          26546.0               85.0           7611576.0        113.0
# 4          16251.0               81.0           7611576.0        113.0
#
# [5 rows x 52 columns]

# %%
category_map = {
    "NSP": "Transit",
    "Content": "Content",
    "Cable/DSL/ISP": "Access",
    "Enterprise": "Enterprise",
    "Educational/Research": "Education/Research",
    "Non-Profit": "Enterprise",
    "Government": "Enterprise",
    "Route Server": "Network Services",
    "Route Collector": "Network Services",
    "Network Services": "Network Services",
    "Not-Disclosed": "Unknown"
}

merged_df["info_type"] = (
    merged_df["info_type"]
    .map(category_map)
    .fillna(merged_df["info_type"])
)
merged_df["info_type"].value_counts()
# Out:
# info_type
# Access                11787
# Transit                3982
# Content                2486
# Enterprise             2460
# Network Services       1458
# Education/Research     1457
# Name: count, dtype: int64

# %%
merged_df["path_origin_ratio"] = merged_df["visibility_path"] / (merged_df["visibility_origin"] + 1e-6)
merged_df.head()
# Out:
#    id  org_id                         name  \
# 0   1    8897  GTT Communications (AS4436)
# 1   2      14          Akamai Technologies
# 2   3      17           DALnet IRC Network
# 3   5    9350                     Swisscom
# 4   6      23           Cox Communications
#
#                                        aka name_long  \
# 0  Formerly known as nLayer Communications
# 1
# 2
# 3                                  IP-Plus
# 4                       Cox Communications
#
#                       website  \
# 0          http://www.gtt.net
# 1     https://www.akamai.com/
# 2          http://www.dal.net
# 3     http://www.swisscom.com
# 4  http://www.cox.com/peering
#
#                                         social_media    asn looking_glass  \
# 0  [{'service': 'website', 'identifier': 'http://...   4436
# 1  [{'service': 'website', 'identifier': 'https:/...  20940
# 2  [{'service': 'website', 'identifier': 'http://...  31800
# 3  [{'service': 'website', 'identifier': 'http://...   3303
# 4  [{'service': 'website', 'identifier': 'http://...  22773
#
#                         route_server  ... seen_peers_origin visibility_origin  \
# 0                                     ...               0.0          0.000000
# 1                                     ...              94.0          0.831858
# 2                                     ...              47.0          0.415929
# 3  telnet://route-server.ip-plus.net  ...              85.0          0.752212
# 4                                     ...              81.0          0.716814
#
#   centrality_mean  endprox_mean  nonterminal_rate path_occurrences  \
# 0        0.506838      0.253419          1.000000             39.0
# 1        0.310215      0.155108          0.629129          25974.0
# 2        0.000000      0.000000          0.000000             39.0
# 3        0.791847      0.395923          0.993558          26546.0
# 4        0.573053      0.286527          0.988001          16251.0
#
#   origin_occurrences total_unique_paths  total_peers  path_origin_ratio
# 0                0.0          7611576.0        113.0      345133.000000
# 1               94.0          7611576.0        113.0           1.010638
# 2               47.0          7611576.0        113.0           0.829786
# 3               85.0          7611576.0        113.0           0.988235
# 4               81.0          7611576.0        113.0           0.999999
#
# [5 rows x 53 columns]

# %% [markdown]
# # Evaluate

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Create boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(data=merged_df, x='info_type', y='visibility_path', showfliers=False)
plt.yscale("log")
plt.xticks(rotation=45)
plt.title('Boxplot of Visibility by Info Type')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Create boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(data=merged_df, x='info_type', y='visibility_origin', showfliers=False)
plt.xticks(rotation=45)
plt.title('Boxplot of Origin Visibility by Info Type')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Create boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(data=merged_df, x='info_type', y='seen_peers_path', showfliers=False)
plt.xticks(rotation=45)
plt.title('Boxplot of Seen Peers by Info Type')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Create boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(data=merged_df, x='info_type', y='path_origin_ratio', showfliers=False)
plt.xticks(rotation=45)
plt.title('Boxplot of Path Origin Ratio by Info Type')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Create boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(data=merged_df, x='info_type', y='seen_peers_origin', showfliers=False)
plt.xticks(rotation=45)
plt.title('Boxplot of Seen Peers Origin by Info Type')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Create boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(data=merged_df, x='info_type', y='seen_peers_origin', showfliers=False)
plt.xticks(rotation=45)
plt.title('Boxplot of Seen Peers Origin by Info Type')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Create boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(data=merged_df, x='info_type', y='centrality_mean', showfliers=False)
plt.xticks(rotation=45)
plt.title('Boxplot of Centrality Mean by Info Type')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Create boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(data=merged_df, x='info_type', y='endprox_mean', showfliers=False)
plt.xticks(rotation=45)
plt.title('Boxplot of End Proximity Mean by Info Type')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Create boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(data=merged_df, x='info_type', y='nonterminal_rate', showfliers=False)
plt.xticks(rotation=45)
plt.title('Boxplot of Nonterminal Rate by Info Type')
plt.show()

# %%
sns.scatterplot(
    data=merged_df,
    x="visibility_origin",
    y="visibility_path",
    alpha=0.5
)
plt.xscale("log"); plt.yscale("log")
